# %% [markdown]
# # Practice from book

# %%
age=int(input())
if age < 4:
    print(f"You're Age is {age} you're Ticket is Free")
elif age > 4 and age <=18:
    print(f"You're Age is {age} you're Ticket is $5")
elif age > 18 and age <=59:
    print(f"You're Age is {age} you're Ticket is $10")
elif age >=60:
    print(f"You're Age is {age} you're Ticket is half")
# Out:
# 70
# You're Age is 70 you're Ticket is half

# %%
alien_color = "green"
if alien_color == "green":
    print("You have just earned 5 point")
if alien_color == "yellow":
    print("You have just earned 10 point")
# Out:
# You have just earned 5 point

# %%
alien_color=input()
if alien_color == "red":
    print("You have earned 5 point")
elif alien_color != "red" and len(alien_color)!=0: #and str.count[:]!=0:
    print("You have earned 10 point")
elif len(alien_color) == 0:
    print("You have not kill any alien ")
# Out:
# You have not kill any alien

# %%
age=int(input())
if age < 2:
    print("You're a baby")
elif age>2 and age<4:
    print("You're a toddler")
elif age == 4 and age < 13:
    print("You're a kid")
elif age== 13 or age < 20:
    print("You're a teenager")
elif age == 20 or age < 65:
    print("You're a adult")
elif age >= 65:
    print("You're a elder")
# Out:
# 556
# You're a elder

# %%
fruit=input()
favorite_fruit=["banana","mango","apple"]
for a in favorite_fruit:
    if a in fruit:
        print(f"you really like {fruit}")
        break
else:
    print(f"You dont like {fruit}")
# Out:
# banana
# you really like banana

# %%
user_name=['tehseen','abdullah','zeeshan','rahim']
name=input()
for a in user_name:
    if a in name or a != name:
        if a == 'rahim':
            print(f"{name} you are future Data Scientist.")
        elif a != name:
            user_name.append(a)
            print(f"{name} you are a new user")
            continue
        else:
            print(f"{name} you also have bright future.")
if len(name) == 0:
    print("please enter a user name")
# Out:
# rahim
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are future Data Scientist.
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# rahim you are a new user
# ...

# %%
user_name
# Out:
# ['tehseen', 'abdullah', 'zeeshan', 'rahim', 'tehseen']

# %%
user_name
# Out:
# ['tehseen', 'abdullah', 'zeeshan', 'rahim', 'tehseen']
